# %% [markdown]
# Importing Libraries

# %%
import pandas as pd
import spacy
import nltk
import math
import numpy as np

nlp = spacy.load("en_core_web_sm")

# %%
from nltk.corpus import stopwords
nltk.download('stopwords')

stop_words = set(stopwords.words('english'))
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\KawaiiAtomic\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %%
from collections import defaultdict

# %% [markdown]
# Importing stemmer for easy implementation of stemmation

# %%
from nltk.stem import PorterStemmer

nlp = spacy.load("en_core_web_sm")
stemmer = PorterStemmer()

# %% [markdown]
# Importing Dataset stored in local directory

# %%
df = pd.read_csv("Articles.csv")
df
# Out:
#                                                 Article       Date  \
# 0     KARACHI: The Sindh government has decided to b...   1/1/2015
# 1     HONG KONG: Asian markets started 2015 on an up...   1/2/2015
# 2     HONG KONG:  Hong Kong shares opened 0.66 perce...   1/5/2015
# 3     HONG KONG: Asian markets tumbled Tuesday follo...   1/6/2015
# 4     NEW YORK: US oil prices Monday slipped below $...   1/6/2015
# ...                                                 ...        ...
# 2687  strong>DUBAI: Dubai International Airport and ...  3/25/2017
# 2688  strong>BEIJING: Former Prime Minister, Shaukat...  3/26/2017
# 2689  strong>WASHINGTON: Uber has grounded its fleet...  3/26/2017
# 2690  strong>BEIJING: The New Development Bank plans...  3/27/2017
# 2691  strong>KARACHI: Karachi-based technology incub...  3/27/2017
#
#                                                 Heading  NewsType
# 0     sindh govt decides to cut public transport far...  business
# 1                       asia stocks up in new year trad  business
# 2              hong kong stocks open 0.66 percent lower  business
# 3                asian stocks sink euro near nine year   business
# 4                    us oil prices slip below 50 a barr  business
# ...                                                 ...       ...
# 2687    Laptop ban hits Dubai for 11m weekend traveller  business
# 2688  Pak China relations not against any third coun...  business
# 2689         Uber grounds self driving cars after accid  business
# 2690  New Development Bank plans joint investments i...  business
# 2691  Google powered Startup Weekend energizing prou...  business
#
# [2692 rows x 4 columns]

# %%
df.tail(10)
# Out:
#                                                 Article       Date  \
# 2682  strong>BEIJING: Beijing's last large coal-fire...  3/19/2017
# 2683  strong>WASHINGTON: The World Bank on Sunday an...  3/20/2017
# 2684  strong>LONDON: Arcelik, the home appliances ar...  3/21/2017
# 2685  strong>RIYADH/DUBAI: Saudi Arabia plans to tig...  3/21/2017
# 2686  strong>BEIJING: A Chinese rail company has won...  3/25/2017
# 2687  strong>DUBAI: Dubai International Airport and ...  3/25/2017
# 2688  strong>BEIJING: Former Prime Minister, Shaukat...  3/26/2017
# 2689  strong>WASHINGTON: Uber has grounded its fleet...  3/26/2017
# 2690  strong>BEIJING: The New Development Bank plans...  3/27/2017
# 2691  strong>KARACHI: Karachi-based technology incub...  3/27/2017
#
#                                                 Heading  NewsType
# 2682  Beijing becomes Chinas first city with all cle...  business
# 2683  World Bank announces 57 bln in financing for Afri  business
# 2684  For Turkish giant Arcelik Pakistan is among fo...  business
# 2685  Saudis to tighten curbs on foreign workers in ...  business
# 2686  Chinese train manufacturer wins railcar bid in US  business
# 2687    Laptop ban hits Dubai for 11m weekend traveller  business
# 2688  Pak China relations not against any third coun...  business
# 2689         Uber grounds self driving cars after accid  business
# 2690  New Development Bank plans joint investments i...  business
# 2691  Google powered Startup Weekend energizing prou...  business

# %% [markdown]
# Removing 'strong>' from the dataset

# %%
df['Article'] = df['Article'].str.replace(r'strong>', '', regex=True)

# %%
df
# Out:
#                                                 Article       Date  \
# 0     KARACHI: The Sindh government has decided to b...   1/1/2015
# 1     HONG KONG: Asian markets started 2015 on an up...   1/2/2015
# 2     HONG KONG:  Hong Kong shares opened 0.66 perce...   1/5/2015
# 3     HONG KONG: Asian markets tumbled Tuesday follo...   1/6/2015
# 4     NEW YORK: US oil prices Monday slipped below $...   1/6/2015
# ...                                                 ...        ...
# 2687  DUBAI: Dubai International Airport and its fla...  3/25/2017
# 2688  BEIJING: Former Prime Minister, Shaukat Aziz s...  3/26/2017
# 2689  WASHINGTON: Uber has grounded its fleet of sel...  3/26/2017
# 2690  BEIJING: The New Development Bank plans to co-...  3/27/2017
# 2691  KARACHI: Karachi-based technology incubator, T...  3/27/2017
#
#                                                 Heading  NewsType
# 0     sindh govt decides to cut public transport far...  business
# 1                       asia stocks up in new year trad  business
# 2              hong kong stocks open 0.66 percent lower  business
# 3                asian stocks sink euro near nine year   business
# 4                    us oil prices slip below 50 a barr  business
# ...                                                 ...       ...
# 2687    Laptop ban hits Dubai for 11m weekend traveller  business
# 2688  Pak China relations not against any third coun...  business
# 2689         Uber grounds self driving cars after accid  business
# 2690  New Development Bank plans joint investments i...  business
# 2691  Google powered Startup Weekend energizing prou...  business
#
# [2692 rows x 4 columns]

# %% [markdown]
# Using numpy for tokenization, nlp for text tokenization

# %%
def tokenize(text):
    if pd.isna(text):
        return []
    doc = nlp(text)      
    return [token.text for token in doc if not token.is_punct]

# %%
df['Heading_Tokens'] = df['Heading'].apply(tokenize)

# %%
df['Article_Tokens'] = df['Article'].apply(tokenize)

# %%
df
# Out:
#                                                 Article       Date  \
# 0     KARACHI: The Sindh government has decided to b...   1/1/2015
# 1     HONG KONG: Asian markets started 2015 on an up...   1/2/2015
# 2     HONG KONG:  Hong Kong shares opened 0.66 perce...   1/5/2015
# 3     HONG KONG: Asian markets tumbled Tuesday follo...   1/6/2015
# 4     NEW YORK: US oil prices Monday slipped below $...   1/6/2015
# ...                                                 ...        ...
# 2687  DUBAI: Dubai International Airport and its fla...  3/25/2017
# 2688  BEIJING: Former Prime Minister, Shaukat Aziz s...  3/26/2017
# 2689  WASHINGTON: Uber has grounded its fleet of sel...  3/26/2017
# 2690  BEIJING: The New Development Bank plans to co-...  3/27/2017
# 2691  KARACHI: Karachi-based technology incubator, T...  3/27/2017
#
#                                                 Heading  NewsType  \
# 0     sindh govt decides to cut public transport far...  business
# 1                       asia stocks up in new year trad  business
# 2              hong kong stocks open 0.66 percent lower  business
# 3                asian stocks sink euro near nine year   business
# 4                    us oil prices slip below 50 a barr  business
# ...                                                 ...       ...
# 2687    Laptop ban hits Dubai for 11m weekend traveller  business
# 2688  Pak China relations not against any third coun...  business
# 2689         Uber grounds self driving cars after accid  business
# 2690  New Development Bank plans joint investments i...  business
# 2691  Google powered Startup Weekend energizing prou...  business
#
#                                          Heading_Tokens  \
# 0     [sindh, govt, decides, to, cut, public, transp...
# 1               [asia, stocks, up, in, new, year, trad]
# 2      [hong, kong, stocks, open, 0.66, percent, lower]
# 3         [asian, stocks, sink, euro, near, nine, year]
# 4           [us, oil, prices, slip, below, 50, a, barr]
# ...                                                 ...
# 2687  [Laptop, ban, hits, Dubai, for, 11, m, weekend...
# 2688  [Pak, China, relations, not, against, any, thi...
# 2689  [Uber, grounds, self, driving, cars, after, ac...
# 2690  [New, Development, Bank, plans, joint, investm...
# 2691  [Google, powered, Startup, Weekend, energizing...
#
#                                          Article_Tokens
# 0     [KARACHI, The, Sindh, government, has, decided...
# 1     [HONG, KONG, Asian, markets, started, 2015, on...
# 2     [HONG, KONG,  , Hong, Kong, shares, opened, 0....
# 3     [HONG, KONG, Asian, markets, tumbled, Tuesday,...
# 4     [NEW, YORK, US, oil, prices, Monday, slipped, ...
# ...                                                 ...
# 2687  [DUBAI, Dubai, International, Airport, and, it...
# 2688  [BEIJING, Former, Prime, Minister, Shaukat, Az...
# 2689  [WASHINGTON, Uber, has, grounded, its, fleet, ...
# 2690  [BEIJING, The, New, Development, Bank, plans, ...
# 2691  [KARACHI, Karachi, based, technology, incubato...
#
# [2692 rows x 6 columns]

# %% [markdown]
# Normalization (Lowering the letters of tokens, replacing capital letters)

# %%
def lowercase_tokens(tokens):
    return [tok.lower() for tok in tokens]

# %%
df['Article_Tokens'] = df['Article_Tokens'].apply(lowercase_tokens)

df['Heading_Tokens'] = df['Heading_Tokens'].apply(lowercase_tokens)

# %%
df
# Out:
#                                                 Article       Date  \
# 0     KARACHI: The Sindh government has decided to b...   1/1/2015
# 1     HONG KONG: Asian markets started 2015 on an up...   1/2/2015
# 2     HONG KONG:  Hong Kong shares opened 0.66 perce...   1/5/2015
# 3     HONG KONG: Asian markets tumbled Tuesday follo...   1/6/2015
# 4     NEW YORK: US oil prices Monday slipped below $...   1/6/2015
# ...                                                 ...        ...
# 2687  DUBAI: Dubai International Airport and its fla...  3/25/2017
# 2688  BEIJING: Former Prime Minister, Shaukat Aziz s...  3/26/2017
# 2689  WASHINGTON: Uber has grounded its fleet of sel...  3/26/2017
# 2690  BEIJING: The New Development Bank plans to co-...  3/27/2017
# 2691  KARACHI: Karachi-based technology incubator, T...  3/27/2017
#
#                                                 Heading  NewsType  \
# 0     sindh govt decides to cut public transport far...  business
# 1                       asia stocks up in new year trad  business
# 2              hong kong stocks open 0.66 percent lower  business
# 3                asian stocks sink euro near nine year   business
# 4                    us oil prices slip below 50 a barr  business
# ...                                                 ...       ...
# 2687    Laptop ban hits Dubai for 11m weekend traveller  business
# 2688  Pak China relations not against any third coun...  business
# 2689         Uber grounds self driving cars after accid  business
# 2690  New Development Bank plans joint investments i...  business
# 2691  Google powered Startup Weekend energizing prou...  business
#
#                                          Heading_Tokens  \
# 0     [sindh, govt, decides, to, cut, public, transp...
# 1               [asia, stocks, up, in, new, year, trad]
# 2      [hong, kong, stocks, open, 0.66, percent, lower]
# 3         [asian, stocks, sink, euro, near, nine, year]
# 4           [us, oil, prices, slip, below, 50, a, barr]
# ...                                                 ...
# 2687  [laptop, ban, hits, dubai, for, 11, m, weekend...
# 2688  [pak, china, relations, not, against, any, thi...
# 2689  [uber, grounds, self, driving, cars, after, ac...
# 2690  [new, development, bank, plans, joint, investm...
# 2691  [google, powered, startup, weekend, energizing...
#
#                                          Article_Tokens
# 0     [karachi, the, sindh, government, has, decided...
# 1     [hong, kong, asian, markets, started, 2015, on...
# 2     [hong, kong,  , hong, kong, shares, opened, 0....
# 3     [hong, kong, asian, markets, tumbled, tuesday,...
# 4     [new, york, us, oil, prices, monday, slipped, ...
# ...                                                 ...
# 2687  [dubai, dubai, international, airport, and, it...
# 2688  [beijing, former, prime, minister, shaukat, az...
# 2689  [washington, uber, has, grounded, its, fleet, ...
# 2690  [beijing, the, new, development, bank, plans, ...
# 2691  [karachi, karachi, based, technology, incubato...
#
# [2692 rows x 6 columns]

# %% [markdown]
# Removing stop words such as of,to... etc.

# %%
def remove_stopwords(tokens):
    return [tok for tok in tokens if tok.lower() not in stop_words]

# %%
df['Article_Tokens'] = df['Article_Tokens'].apply(remove_stopwords)
df['Heading_Tokens'] = df['Heading_Tokens'].apply(remove_stopwords)

# %%
df
# Out:
#                                                 Article       Date  \
# 0     KARACHI: The Sindh government has decided to b...   1/1/2015
# 1     HONG KONG: Asian markets started 2015 on an up...   1/2/2015
# 2     HONG KONG:  Hong Kong shares opened 0.66 perce...   1/5/2015
# 3     HONG KONG: Asian markets tumbled Tuesday follo...   1/6/2015
# 4     NEW YORK: US oil prices Monday slipped below $...   1/6/2015
# ...                                                 ...        ...
# 2687  DUBAI: Dubai International Airport and its fla...  3/25/2017
# 2688  BEIJING: Former Prime Minister, Shaukat Aziz s...  3/26/2017
# 2689  WASHINGTON: Uber has grounded its fleet of sel...  3/26/2017
# 2690  BEIJING: The New Development Bank plans to co-...  3/27/2017
# 2691  KARACHI: Karachi-based technology incubator, T...  3/27/2017
#
#                                                 Heading  NewsType  \
# 0     sindh govt decides to cut public transport far...  business
# 1                       asia stocks up in new year trad  business
# 2              hong kong stocks open 0.66 percent lower  business
# 3                asian stocks sink euro near nine year   business
# 4                    us oil prices slip below 50 a barr  business
# ...                                                 ...       ...
# 2687    Laptop ban hits Dubai for 11m weekend traveller  business
# 2688  Pak China relations not against any third coun...  business
# 2689         Uber grounds self driving cars after accid  business
# 2690  New Development Bank plans joint investments i...  business
# 2691  Google powered Startup Weekend energizing prou...  business
#
#                                          Heading_Tokens  \
# 0     [sindh, govt, decides, cut, public, transport,...
# 1                       [asia, stocks, new, year, trad]
# 2      [hong, kong, stocks, open, 0.66, percent, lower]
# 3         [asian, stocks, sink, euro, near, nine, year]
# 4                     [us, oil, prices, slip, 50, barr]
# ...                                                 ...
# 2687  [laptop, ban, hits, dubai, 11, weekend, travel...
# 2688  [pak, china, relations, third, country, shauka...
# 2689        [uber, grounds, self, driving, cars, accid]
# 2690  [new, development, bank, plans, joint, investm...
# 2691  [google, powered, startup, weekend, energizing...
#
#                                          Article_Tokens
# 0     [karachi, sindh, government, decided, bring, p...
# 1     [hong, kong, asian, markets, started, 2015, up...
# 2     [hong, kong,  , hong, kong, shares, opened, 0....
# 3     [hong, kong, asian, markets, tumbled, tuesday,...
# 4     [new, york, us, oil, prices, monday, slipped, ...
# ...                                                 ...
# 2687  [dubai, dubai, international, airport, flag, c...
# 2688  [beijing, former, prime, minister, shaukat, az...
# 2689  [washington, uber, grounded, fleet, self, driv...
# 2690  [beijing, new, development, bank, plans, co, f...
# 2691  [karachi, karachi, based, technology, incubato...
#
# [2692 rows x 6 columns]

# %% [markdown]
# Lemmatization/Stemmation

# %%
def lemmatize_and_stem(tokens):
    doc = nlp(" ".join(tokens))  
    processed_tokens = []

    for token in doc:
        lemma = token.lemma_.lower()  
        stemmed = stemmer.stem(lemma) 
        processed_tokens.append(stemmed)

    return processed_tokens

# %%
df['Article_Tokens'] = df['Article_Tokens'].apply(lemmatize_and_stem)
df['Heading_Tokens'] = df['Heading_Tokens'].apply(lemmatize_and_stem)

# %%
df
# Out:
#                                                 Article       Date  \
# 0     KARACHI: The Sindh government has decided to b...   1/1/2015
# 1     HONG KONG: Asian markets started 2015 on an up...   1/2/2015
# 2     HONG KONG:  Hong Kong shares opened 0.66 perce...   1/5/2015
# 3     HONG KONG: Asian markets tumbled Tuesday follo...   1/6/2015
# 4     NEW YORK: US oil prices Monday slipped below $...   1/6/2015
# ...                                                 ...        ...
# 2687  DUBAI: Dubai International Airport and its fla...  3/25/2017
# 2688  BEIJING: Former Prime Minister, Shaukat Aziz s...  3/26/2017
# 2689  WASHINGTON: Uber has grounded its fleet of sel...  3/26/2017
# 2690  BEIJING: The New Development Bank plans to co-...  3/27/2017
# 2691  KARACHI: Karachi-based technology incubator, T...  3/27/2017
#
#                                                 Heading  NewsType  \
# 0     sindh govt decides to cut public transport far...  business
# 1                       asia stocks up in new year trad  business
# 2              hong kong stocks open 0.66 percent lower  business
# 3                asian stocks sink euro near nine year   business
# 4                    us oil prices slip below 50 a barr  business
# ...                                                 ...       ...
# 2687    Laptop ban hits Dubai for 11m weekend traveller  business
# 2688  Pak China relations not against any third coun...  business
# 2689         Uber grounds self driving cars after accid  business
# 2690  New Development Bank plans joint investments i...  business
# 2691  Google powered Startup Weekend energizing prou...  business
#
#                                          Heading_Tokens  \
# 0     [sindh, govt, decid, cut, public, transport, f...
# 1                        [asia, stock, new, year, trad]
# 2       [hong, kong, stock, open, 0.66, percent, lower]
# 3          [asian, stock, sink, euro, near, nine, year]
# 4                      [we, oil, price, slip, 50, barr]
# ...                                                 ...
# 2687     [laptop, ban, hit, dubai, 11, weekend, travel]
# 2688  [pak, china, relat, third, countri, shaukat, a...
# 2689            [uber, ground, self, drive, car, accid]
# 2690  [new, develop, bank, plan, joint, invest, econ...
# 2691  [googl, power, startup, weekend, energ, proud,...
#
#                                          Article_Tokens
# 0     [karachi, sindh, govern, decid, bring, public,...
# 1     [hong, kong, asian, market, start, 2015, upsw,...
# 2     [hong, kong,   , hong, kong, share, open, 0.66...
# 3     [hong, kong, asian, market, tumbl, tuesday, fo...
# 4     [new, york, us, oil, price, monday, slip, $, 5...
# ...                                                 ...
# 2687  [dubai, dubai, intern, airport, flag, carrier,...
# 2688  [beij, former, prime, minist, shaukat, aziz, s...
# 2689  [washington, uber, ground, fleet, self, drive,...
# 2690  [beij, new, develop, bank, plan, co, financ, i...
# 2691  [karachi, karachi, base, technolog, incub, nes...
#
# [2692 rows x 6 columns]

# %% [markdown]
# Indicing -> Inverted Index

# %%
def build_inverted_index(df, column="Article_Tokens"):
    index = defaultdict(dict)

    for doc_id, tokens in enumerate(df[column]):
        for term in tokens:
            if term not in index or doc_id not in index[term]:
                index[term][doc_id] = 0
            index[term][doc_id] += 1  
    
    return index

# %%
inverted_index = build_inverted_index(df)
print("Total indexed terms:", len(inverted_index))
# Out:
# Total indexed terms: 26421

# %%
#inverted_index

# %% [markdown]
# Computing IDF scores

# %%
def compute_idf(index, total_docs):
    idf = {}
    for term, doc_dict in index.items():
        df = len(doc_dict) 
        idf[term] = math.log((total_docs / df), 10) 
    return idf

# %%
total_docs = len(df)

# %%
idf_scores = compute_idf(inverted_index, total_docs)
#idf_scores

# %% [markdown]
# Computing tf scores

# %%
def compute_tf(index):
    tf = {} 
    for term, doc_dict in index.items():
        tf[term] = {}
        for doc, freq in doc_dict.items():
            tf[term][doc] = freq  
    return tf

# %%
tf_scores = compute_tf(inverted_index)
#tf_scores

# %% [markdown]
# Computing tf-idf scores

# %%
def compute_tf_idf(tf_scores, idf_scores):
    
    tf_idf = {}

    for term in tf_scores:
        tf_idf[term] = {}

        for doc, tf_val in tf_scores[term].items():
            tf_idf[term][doc] = tf_val * idf_scores[term]  # TF-IDF score

    return tf_idf

# %%
tf_idf_matrix = compute_tf_idf(tf_scores, idf_scores)
#tf_idf_matrix

# %% [markdown]
# Building Document Vectors

# %%
def build_document_vectors(tf_idf_matrix, total_docs):
    vocab = list(tf_idf_matrix.keys())                 
    vectors = {doc: np.zeros(len(vocab)) for doc in range(total_docs)}
    for term_index, term in enumerate(vocab):
        for doc, score in tf_idf_matrix[term].items():

            vectors[doc][term_index] = score          

    return vectors, vocab

document_vectors, vocabulary = build_document_vectors(tf_idf_matrix, total_docs)
#document_vectors

# %% [markdown]
# Norm imported from linalg(linear algebra) package of numpy for cosine similarity

# %%
from numpy.linalg import norm

# %%
def cosine_similarity(vec_a, vec_b):
    if norm(vec_a) == 0 or norm(vec_b) == 0:
        return 0
    return np.dot(vec_a, vec_b) / (norm(vec_a) * norm(vec_b))

# %% [markdown]
# Rankinf Documents based on relevance

# %%
def rank_documents(query_tokens, document_vectors, tf_idf_matrix, vocabulary):
    query_vec = np.zeros(len(vocabulary))

    for token in query_tokens:
        if token in tf_idf_matrix:
            term_index = vocabulary.index(token)
            query_vec[term_index] = sum(tf_idf_matrix[token].values())

    #cosine similarity function called below
    similarities = []
    for doc_id, doc_vec in document_vectors.items():
        score = cosine_similarity(query_vec, doc_vec)
        similarities.append((doc_id, score))

    ranked = sorted(similarities, key=lambda x: x[1], reverse=True)
    return ranked

# %% [markdown]
# User inputs query here

# %%
query = input("Enter search query: ").lower().split()

# %%
query
# Out:
# ['islamabad']

# %% [markdown]
# Ranks documents and returns result based on the user input query

# %%
# query = lemmatize_and_stem(remove_stopwords(lowercase_tokens(query)))

results = rank_documents(query, document_vectors, tf_idf_matrix, vocabulary)

print("Top Ranked Documents:")
for rank, (doc, score) in enumerate(results[:5], start=1):  
    print(rank, "Document ID :", doc, "having score = ", score)

    print("→ Heading:", df.iloc[doc]['Heading'])
    print("→ Article:", df.iloc[doc]['Article'][:200], "...")
    print("--------------------------------------------------")
# Out:
# Top Ranked Documents:
# 1 Document ID : 1164 having score =  0.2023861045326962
# → Heading: Wright steers Quetta to easy win against Islamabad in PSL opener
# → Article: DUBAI: England�s T20 expert Luke Wright scored impressive 86 to steer Quetta Gladiators to their first triumph against Islamabad United at the opening match of Pakistan Super League (PSL) by 8 wickets ...
# --------------------------------------------------
# 2 Document ID : 428 having score =  0.18944555521336057
# → Heading: Ishaq Dar formally launches Pakistan Stock Exchang
# → Article: ISLAMABAD: Pakistan stock Exchange (PSX) has been formally launched after integration of all the three bourses of the country.</strongMinister for Finance Ishaq Dar on Monday inaugurated the PSX, form ...
# --------------------------------------------------
# 3 Document ID : 1277 having score =  0.18435470956574163
# → Heading: Karachi eliminated Islamabad to play Peshawar
# → Article: DUBAI: Islamabad United defeated Karachi Kings by nine wickets in the second qualifying final of the Pakistan Super League here at the Dubai International Cricket Stadium at Saturday night.Thus, Karac ...
# --------------------------------------------------
# 4 Document ID : 1281 having score =  0.17415565228335264
# → Heading: Shehzad Sanga help Quetta set 175 for Islamabad
# → Article: DUBAI: Ahmed Shehzad and Kumar Sangakkara struck dashing fifties to steer Quetta Gladiators to a big total of 174 runs for seven wickets against Islamabad United in the final of the first Pakistan Sup ...
# --------------------------------------------------
# 5 Document ID : 1191 having score =  0.17260620982408148
# → Heading: Lahore set 167 run target for Islamabad
# → Article: SHARJAH: Lahore Qalandars set a rather difficult target of 167 runs for Islamabad United in the ninth Twenty20 match of the Pakistan Super League 2016 here on Wednesday.After sent into bat by Islamaba ...
# --------------------------------------------------
